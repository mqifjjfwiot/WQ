# %% [markdown]
# <a href="https://colab.research.google.com/github/mqifjjfwiot/WQ/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%EC%9C%BC%EB%A1%9C%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%A3%BC%EB%AC%B4%EB%A5%B4%EA%B8%B0/2_%EC%84%9C%EC%9A%B8%EC%8B%9C_%EB%B2%94%EC%A3%84_%ED%98%84%ED%99%A9_%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 2s (6,126 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 120874 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import pandas as pd
# 시각화 도구
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns

# %%
plt.rc('font', family='NanumBarunGothic')

# %%
# 한글 폰트가 제대로 설정되었는지 확인
########### 설정 한 뒤 반드시 런타임 재시작 해야 적용됨. 반드시!!
plt.text(0.5, 0.5, '한글 텍스트', size=18)  # 플롯에 한글 텍스트 추가
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 파이썬으로 데이터 주무르기/

# %%
# 서울시 자치구 년도별 CCTV 설치 현황_230630기준.csv
# /content/drive/MyDrive/Colab Notebooks/WQ/파이썬으로 데이터 주무르기 4주완성/Data/서울시 자치구 년도별 CCTV 설치 현황_230630기준.csv
crime_anal_seoul = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/WQ/파이썬으로 데이터 주무르기 4주완성/Data/5대+범죄+발생현황_20231024141401.xlsx', thousands=',')
crime_anal_seoul.head(7)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    자치구별(1)  자치구별(2)   2022 2022.1 2022.2 2022.3 2022.4 2022.5   2022.6  \
# 0  자치구별(1)  자치구별(2)     합계     합계     합계     합계     합계     합계       합계
# 1  자치구별(1)  자치구별(2)     소계     소계     살인     살인     강도     강도  강간·강제추행
# 2  자치구별(1)  자치구별(2)     발생     검거     발생     검거     발생     검거       발생
# 3       합계       소계  90399  65097    104     98    117    112     5816
# 4      NaN      종로구   3138   3284      2      3      8      8      228
# 5      NaN       중구   3071   2119      1      2      5      4      194
# 6      NaN      용산구   2967   2093      5      3      7      7      280
#
#     2022.7 2022.8 2022.9 2022.10 2022.11
# 0       합계     합계     합계      합계      합계
# 1  강간·강제추행     절도     절도      폭력      폭력
# 2       검거     발생     검거      발생      검거
# 3     5344  37579  20205   46783   39338
# 4      988   1313    932    1587    1353
# 5      123   1365    724    1506    1266
# 6      238    978    508    1697    1337

# %%
crime_anal_seoul.size
len(crime_anal_seoul)
len(crime_anal_seoul.columns)
# Out:
# 14

# %%
crime_anal_seoul = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/WQ/파이썬으로 데이터 주무르기 4주완성/Data/5대+범죄+발생현황_20231024141401.xlsx', header=2,thousands=',')
crime_anal_seoul.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    자치구별(1)  자치구별(2)     소계   소계.1   살인 살인.1   강도 강도.1 강간·강제추행 강간·강제추행.1  \
# 0  자치구별(1)  자치구별(2)     발생     검거   발생   검거   발생   검거      발생        검거
# 1       합계       소계  90399  65097  104   98  117  112    5816      5344
# 2      NaN      종로구   3138   3284    2    3    8    8     228       988
# 3      NaN       중구   3071   2119    1    2    5    4     194       123
# 4      NaN      용산구   2967   2093    5    3    7    7     280       238
#
#       절도   절도.1     폭력   폭력.1
# 0     발생     검거     발생     검거
# 1  37579  20205  46783  39338
# 2   1313    932   1587   1353
# 3   1365    724   1506   1266
# 4    978    508   1697   1337

# %%
crime_anal_seoul2 = crime_anal_seoul.copy()

# %%
crime_anal_seoul2.columns = crime_anal_seoul2.columns.str.replace('.1', '검거')
crime_anal_seoul2.head()
# Out:
# <ipython-input-11-29a7dce1ecf7>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   crime_anal_seoul2.columns = crime_anal_seoul2.columns.str.replace('.1', '검거')
#    자치구별검거)  자치구별(2)     소계   소계검거   살인 살인검거   강도 강도검거 강간·강제추행 강간·강제추행검거  \
# 0  자치구별(1)  자치구별(2)     발생     검거   발생   검거   발생   검거      발생        검거
# 1       합계       소계  90399  65097  104   98  117  112    5816      5344
# 2      NaN      종로구   3138   3284    2    3    8    8     228       988
# 3      NaN       중구   3071   2119    1    2    5    4     194       123
# 4      NaN      용산구   2967   2093    5    3    7    7     280       238
#
#       절도   절도검거     폭력   폭력검거
# 0     발생     검거     발생     검거
# 1  37579  20205  46783  39338
# 2   1313    932   1587   1353
# 3   1365    724   1506   1266
# 4    978    508   1697   1337

# %%
# 1행 드랍, 인덱스리셋
crime_anal_seoul2 = crime_anal_seoul2.drop([0,1])
crime_anal_seoul2 = crime_anal_seoul2.reset_index(drop=True)

# 자치구별검거) 열 삭제
crime_anal_seoul2 = crime_anal_seoul2.drop(columns=['자치구별검거)','소계','소계검거'])

crime_anal_seoul2.head()
# Out:
#   자치구별(2) 살인 살인검거 강도 강도검거 강간·강제추행 강간·강제추행검거    절도 절도검거    폭력  폭력검거
# 0     종로구  2    3  8    8     228       988  1313  932  1587  1353
# 1      중구  1    2  5    4     194       123  1365  724  1506  1266
# 2     용산구  5    3  7    7     280       238   978  508  1697  1337
# 3     성동구  2    2  2    2     125        97   979  538  1086   958
# 4     광진구  6    5  -    -     230       174  1670  831  1713  1488

# %%
# 첫 칼럼 이름 변경
crime_anal_seoul2.rename(columns = {'자치구별(2)' : '구별'}, inplace = True)
crime_anal_seoul2.head()
# Out:
#     구별 살인 살인검거 강도 강도검거 강간·강제추행 강간·강제추행검거    절도 절도검거    폭력  폭력검거
# 0  종로구  2    3  8    8     228       988  1313  932  1587  1353
# 1   중구  1    2  5    4     194       123  1365  724  1506  1266
# 2  용산구  5    3  7    7     280       238   978  508  1697  1337
# 3  성동구  2    2  2    2     125        97   979  538  1086   958
# 4  광진구  6    5  -    -     230       174  1670  831  1713  1488

# %%
crime_anal_seoul3 = crime_anal_seoul2.copy()

# %%
# 데이터값이 혼재되어 있을때는 일괄 전환하거나 일치시키는 방법은 없는것같다.
# 전처리의 일환으로 여기고 수작업 전환해주자
crime_anal_seoul3.loc[4,['강도','강도검거']] = 0
crime_anal_seoul3.loc[9,['강도','강도검거']] = 0

# %%
crime_anal_seoul3
# Out:
#       구별  살인 살인검거  강도 강도검거 강간·강제추행 강간·강제추행검거    절도  절도검거    폭력  폭력검거
# 0    종로구   2    3   8    8     228       988  1313   932  1587  1353
# 1     중구   1    2   5    4     194       123  1365   724  1506  1266
# 2    용산구   5    3   7    7     280       238   978   508  1697  1337
# 3    성동구   2    2   2    2     125        97   979   538  1086   958
# 4    광진구   6    5   0    0     230       174  1670   831  1713  1488
# 5   동대문구   4    4   2    2     125       106  1556   823  1566  1296
# 6    중랑구   2    2   2    2     150       121  1508   882  1937  1664
# 7    성북구   3    3   1    1     158       129  1143   715  1444  1277
# 8    강북구   5    4   5    6     177       147   872   589  1773  1597
# 9    도봉구   3    3   0    0      70        54   969   546  1099   966
# 10   노원구   3    3   3    1     180       151  1504   729  2206  1757
# 11   은평구   4    4   5    4     176       146  1497   946  1805  1558
# 12  서대문구   5    4   6    6     157       144  1114   565  1092   886
# 13   마포구   2    2   2    1     436       368  1451   653  2205  1790
# 14   양천구   2    2   3    3     114        92  1474   781  1576  1252
# 15   강서구   3    3   7    7     261       195  1991  1185  2401  2201
# 16   구로구  11   11   8    9     217       145  1565   841  2056  1726
# 17   금천구   2    1   3    3     127        87  1118   662  1327  1134
# 18  영등포구   5    6  10    9     327       237  2062   953  2415  1981
# 19   동작구   2    3   5    5     212       107  1195   588  1321  1038
# 20   관악구  10    8   9    8     327       279  1966  1050  2567  2066
# 21   서초구   3    2   3    3     431       328  1921  1024  2101  1741
# 22   강남구  12   10  11   10     667       534  2495  1207  3762  3259
# 23   송파구   2    2   5    6     290       220  2201  1033  2669  2148
# 24   강동구   5    6   5    5     157       134  1672   900  1872  1599

# %%
# 전환 후 일괄 정수화
for c in crime_anal_seoul3.columns :
  if c == '구별' :
    pass
  else :
    crime_anal_seoul3[c].astype(int)
crime_anal_seoul3.head()
# Out:
#     구별 살인 살인검거 강도 강도검거 강간·강제추행 강간·강제추행검거    절도 절도검거    폭력  폭력검거
# 0  종로구  2    3  8    8     228       988  1313  932  1587  1353
# 1   중구  1    2  5    4     194       123  1365  724  1506  1266
# 2  용산구  5    3  7    7     280       238   978  508  1697  1337
# 3  성동구  2    2  2    2     125        97   979  538  1086   958
# 4  광진구  6    5  0    0     230       174  1670  831  1713  1488

# %%
crime_anal_seoul3 = crime_anal_seoul3.set_index('구별')
crime_anal_seoul3.head()
# Out:
#     살인 살인검거 강도 강도검거 강간·강제추행 강간·강제추행검거    절도 절도검거    폭력  폭력검거
# 구별
# 종로구  2    3  8    8     228       988  1313  932  1587  1353
# 중구   1    2  5    4     194       123  1365  724  1506  1266
# 용산구  5    3  7    7     280       238   978  508  1697  1337
# 성동구  2    2  2    2     125        97   979  538  1086   958
# 광진구  6    5  0    0     230       174  1670  831  1713  1488

# %%
crime_anal_seoul3['살인검거율'] = crime_anal_seoul3['살인검거'] / crime_anal_seoul3['살인'] * 100
# 값에 0이 있는 강도 칼럼 강제 0%로 에외처리
# itterrows는 데프에만 쓸수있다.
# row 활용해서 식 세울수도 있다
for id, row in crime_anal_seoul3.iterrows() :
  try :
    crime_anal_seoul3.loc[id, '강도검거율'] = crime_anal_seoul3.loc[id, '강도검거'] / crime_anal_seoul3.loc[id, '강도'] * 100
  except ZeroDivisionError :
    crime_anal_seoul3.loc[id, '강도검거율'] = 0

crime_anal_seoul3['강간추행검거율'] = crime_anal_seoul3['강간·강제추행검거'] / crime_anal_seoul3['강간·강제추행'] * 100
crime_anal_seoul3['절도검거율'] = crime_anal_seoul3['절도검거'] / crime_anal_seoul3['절도'] * 100
crime_anal_seoul3['폭력검거율'] = crime_anal_seoul3['폭력검거'] / crime_anal_seoul3['폭력'] * 100
crime_anal_seoul3
# Out:
#       살인 살인검거  강도 강도검거 강간·강제추행 강간·강제추행검거    절도  절도검거    폭력  폭력검거      살인검거율  \
del crime_anal_seoul3['절도검거']
del crime_anal_seoul3['폭력검거']
# 배율이 100을 넘는 놈들은 100으로 정리.
con_list = crime_anal_seoul3.columns[-5:]

# loc기반으로 조건을 성립하는 행, 열 을 100으로 교체
for c in con_list :
  crime_anal_seoul3.loc[ crime_anal_seoul3[c]>100 , c] = 100

crime_anal_seoul3
# Out:
#       살인  강도 강간·강제추행    절도    폭력      살인검거율       강도검거율    강간추행검거율      절도검거율  \
# 구별
# 종로구    2   8     228  1313  1587        100  100.000000        100  70.982483
# 중구     1   5     194  1365  1506        100   80.000000  63.402062  53.040293
# 용산구    5   7     280   978  1697       60.0  100.000000       85.0   51.94274
# 성동구    2   2     125   979  1086      100.0  100.000000       77.6  54.954035
# 광진구    6   0     230  1670  1713  83.333333    0.000000  75.652174  49.760479
# 동대문구   4   2     125  1556  1566      100.0  100.000000       84.8  52.892031
# 중랑구    2   2     150  1508  1937      100.0  100.000000  80.666667  58.488064
# 성북구    3   1     158  1143  1444      100.0  100.000000   81.64557  62.554681
# 강북구    5   5     177   872  1773       80.0  100.000000  83.050847  67.545872
# 도봉구    3   0      70   969  1099      100.0    0.000000  77.142857  56.346749
# 노원구    3   3     180  1504  2206      100.0   33.333333  83.888889  48.470745
# 은평구    4   5     176  1497  1805      100.0   80.000000  82.954545  63.193053
# 서대문구   5   6     157  1114  1092       80.0  100.000000  91.719745  50.718133
# 마포구    2   2     436  1451  2205      100.0   50.000000   84.40367  45.003446
# 양천구    2   3     114  1474  1576      100.0  100.000000  80.701754  52.985075
# 강서구    3   7     261  1991  2401      100.0  100.000000  74.712644   59.51783
# 구로구   11   8     217  1565  2056      100.0  100.000000  66.820276  53.738019
# 금천구    2   3     127  1118  1327       50.0  100.000000  68.503937   59.21288
# 영등포구   5  10     327  2062  2415        100   90.000000  72.477064  46.217265
# 동작구    2   5     212  1195  1321        100  100.000000  50.471698  49.205021
# 관악구   10   9     327  1966  2567       80.0   88.888889  85.321101  53.407935
# 서초구    3   3     431  1921  2101  66.666667  100.000000  76.102088   53.30557
# 강남구   12  11     667  2495  3762  83.333333   90.909091   80.05997  48.376754
# 송파구    2   5     290  2201  2669      100.0  100.000000  75.862069  46.933212
# 강동구    5   5     157  1672  1872        100  100.000000  85.350318  53.827751
#
#           폭력검거율
# 구별
# 종로구   85.255198
# 중구    84.063745
# 용산구   78.786093
# 성동구   88.213628
# 광진구   86.865149
# 동대문구  82.758621
# 중랑구    85.90604
# 성북구   88.434903
# 강북구   90.073322
# 도봉구   87.898089
# 노원구   79.646419
# 은평구   86.315789
# 서대문구  81.135531
# 마포구   81.179138
# 양천구   79.441624
# 강서구   91.670137
# 구로구   83.949416
# 금천구   85.455916
# 영등포구  82.028986
# 동작구   78.576836
# 관악구   80.483054
# 서초구   82.865302
# 강남구   86.629452
# 송파구    80.47958
# 강동구   85.416667

# %%
# 데이터 표현을 위해 다듬기
# 정규화. 살인처럼 소수 발생하는 사건과 수천건 발생하는 절도를 공정히 비교하게 하기 위함.
from sklearn import preprocessing

# %%
col = crime_anal_seoul3.columns[:5]
# 집어넣은 값 선정. 열 별로
x = crime_anal_seoul3[col].values
# 스케일러 객체 생성
min_max_scaler = preprocessing.MinMaxScaler()
# 현재는 int타입. 어차피 계산하면 실수로 바뀌지 않나
x_scaled = min_max_scaler.fit_transform(x.astype(float))
# 바꾼값 그대로 col 붙이고 인덱스 길이 맞춰서 새 데프 선언
crime_anal_norm = pd.DataFrame(x_scaled, columns = col, index = crime_anal_seoul3.index)

# %%
col
# Out:
# Index(['살인', '강도', '강간·강제추행', '절도', '폭력'], dtype='object')

# %%
# 검거율 이식
crime_anal_norm[con_list] = crime_anal_seoul3[con_list]
crime_anal_norm.head(7)
# Out:
#             살인        강도   강간·강제추행        절도        폭력      살인검거율  강도검거율  \
# 구별
# 종로구   0.090909  0.727273  0.264657  0.271719  0.187220        100  100.0
# 중구    0.000000  0.454545  0.207705  0.303758  0.156951        100   80.0
# 용산구   0.363636  0.636364  0.351759  0.065311  0.228326       60.0  100.0
# 성동구   0.090909  0.181818  0.092127  0.065927  0.000000      100.0  100.0
# 광진구   0.454545  0.000000  0.268007  0.491682  0.234305  83.333333    0.0
# 동대문구  0.272727  0.181818  0.092127  0.421442  0.179372      100.0  100.0
# 중랑구   0.090909  0.181818  0.134003  0.391867  0.318012      100.0  100.0
#
#         강간추행검거율      절도검거율      폭력검거율
# 구별
# 종로구         100  70.982483  85.255198
# 중구    63.402062  53.040293  84.063745
# 용산구        85.0   51.94274  78.786093
# 성동구        77.6  54.954035  88.213628
# 광진구   75.652174  49.760479  86.865149
# 동대문구       84.8  52.892031  82.758621
# 중랑구   80.666667  58.488064   85.90604

# %%
# 1장으로 돌아가 결과물 저장 후 출력
# /content/drive/MyDrive/Colab Notebooks/WQ/파이썬으로 데이터 주무르기 4주완성/Data/서울시 자치구 년도별 CCTV 설치 현황_230630기준.csv
CCTV_Seoul = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/WQ/파이썬으로 데이터 주무르기 4주완성/Data/01.result_CCTV.csv')
CCTV_Seoul = CCTV_Seoul.set_index('구별')
CCTV_Seoul.head()
# Out:
#        총계       최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 구별
# 종로구  1966   63.852243  152212  141060  11152  28265  7.326623  18.569495
# 중구   2584   72.777395  131390  120963  10427  25353  7.935916  19.295989
# 용산구  2970  170.961718  232482  217756  14726  39478  6.334254  16.981100
# 성동구  4175   84.521108  287240  280240   7000  48238  2.436986  16.793622
# 광진구  3592  145.578720  350925  336801  14124  54854  4.024792  15.631260

# %%
# 순서가 제각각이니 구별을 기준으로 양 데이터 프레임 맞춰주기
CCTV_Seoul = CCTV_Seoul.sort_index()
CCTV_Seoul.head()
# Out:
#        총계       최근증가율     인구수     한국인    외국인    고령자     외국인비율      고령자비율
# 구별
# 강남구  7243   67.798742  537817  532798   5019  83097  0.933217  15.450795
# 강동구  3192  122.885572  464027  459982   4045  79706  0.871717  17.177018
# 강북구  3321  387.463127  296934  292762   4172  67056  1.405026  22.582796
# 강서구  3353  150.835322  573711  568287   5424  98659  0.945424  17.196637
# 관악구  5642   79.731993  502628  487815  14813  83420  2.947110  16.596767

# %%
crime_anal_norm = crime_anal_norm.sort_index()
crime_anal_norm.head()
# Out:
#            살인        강도   강간·강제추행        절도        폭력      살인검거율       강도검거율  \
# 구별
# 강남구  1.000000  1.000000  1.000000  1.000000  1.000000  83.333333   90.909091
# 강서구  74.712644   59.51783  91.670137  573711  3353  2.318984  425.900611
# 관악구  85.321101  53.407935  80.483054  502628  5642  3.294348  388.100979

# %%
# # seaborn
# import matplotlib.pyplot as plt
# %matplotlib inline
#### seaborn을 새로 불러오면 이전의 글씨폰트 지정이 해제되는듯하다. 쓸거면 같이 불러놓고 바꾸자.

# %%
# 기본 삼각함수들
# 정의역, 간격 설정
x = np.linspace(0,14,100)
y1 = np.sin(x)
y2 = 2*np.sin(x+0.5)
y3 = 3*np.sin(x+1.0)
y4 = 4*np.sin(x+1.5)

plt.figure(figsize=(5,3))
# 동일 조건으로 여러개 그릴땐 편리. 별도 옵션 달아주거나 할때는 각각 .plot 해도 됨
plt.plot(x,y1, x,y2, x,y3, x,y4)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 격자와 축이 밝은 회색으로
sns.set_style('whitegrid')

plt.figure(figsize=(5,3))
plt.plot(x,y1, x,y2, x,y3, x,y4)
plt.show()

# %%
# 연습 데이터셋
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# # 박스플롯. 범위와 표준편차, 이상치 표기에 특화
# # mat만 썼을때
# s1 = np.random.normal(loc = 0, scale =1, size = 1000)
# s2 = np.random.normal(loc = 5, scale =0.5, size = 1000)
# s3 = np.random.normal(loc = 10, scale =2, size = 1000)
# plt.figure(figsize = (5,3))
# plt.boxplot((s1, s2, s3))
# plt.grid()
# plt.show()

plt.figure(figsize=(4,3))
sns.boxplot(x='day', y='total_bill', data=tips)
plt.show()

# %%
plt.figure(figsize=(4,3))
# hue로 변수별 구분 표기도 가능. 색깔 변경도.
sns.boxplot(x='day', y='total_bill', hue='smoker', data=tips, palette = 'Set3')
plt.show()

# %%
# lmplot : 데이터를 scatter로 흩뿌리고 회귀 직선과 유효범위까지.
sns.set_style("darkgrid")
# sns.lmplot(x="total_bill", y="tip", data=tips, size=7) 그래프의 크기를 조정하는 파라미터 size는 현재 쓰이지 않음. height로 대체.
sns.lmplot(x="total_bill", y="tip", data=tips, height=5)
plt.show()

# %%
# 구분, 팔레트
sns.lmplot(x="total_bill", y="tip", hue='smoker', data=tips, palette = 'Set1' ,height=5)
plt.show()

# %%
# 샘플데이터2 - 연/월/탑승자
flights = sns.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
# df.pivot(행(index), 열(column), 데이터값)
flights = flights.pivot("month", "year", "passengers")
flights.head()
# Out:
# <ipython-input-41-b35ef70e456d>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights = flights.pivot("month", "year", "passengers")
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472

# %%
# annot : 각 셀의 값 표기여부, fmt : 그 값이 어떤 형식인지(d는 정수, '.2f'는 소수 둘째자리까지 등)
plt.figure(figsize=(10,8))
sns.heatmap(flights, annot=True, fmt='d')
plt.show()

# %%
# 샘플 데이터셋 3 - 아이리스
sns.set(style='ticks')
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# species(3종) 구분자로 구별해 각 변수별 피벗으로 나오는 모든 도표 표기
sns.pairplot(iris, hue='species')
plt.show()

# %%
# 정규화한 데이터에서 중범죄 상관관계
sns.pairplot(crime_anal_norm, vars=["강도", "살인", "폭력"], kind='reg', height=3)
plt.show()

# %%
# 정규화한 데이터에서 중범죄 상관관계
# x변수와 y변수 별도 지정 가능. 이거면 4*4 다 안만들어도 되겠네
sns.pairplot(crime_anal_norm, x_vars=["인구수", "CCTV"], y_vars=["살인", "강도"], kind='reg', height=3)
plt.show()

# %%
crime_anal_norm.head()
# Out:
#            살인        강도   강간·강제추행        절도        폭력       살인검거율       강도검거율  \
# 구별
# 강남구  1.000000  1.000000  1.000000  1.000000  1.000000   83.333333   90.909091
# 강동구  0.363636  0.454545  0.145729  0.492914  0.293722  100.000000  100.000000
# 강북구  0.363636  0.454545  0.179229  0.000000  0.256726   80.000000  100.000000
# 강서구  0.181818  0.636364  0.319933  0.689464  0.491405  100.000000  100.000000
# 관악구  0.818182  0.818182  0.430486  0.674060  0.553438   80.000000   88.888889
#
#        강간추행검거율      절도검거율      폭력검거율       인구수    CCTV        범죄         검거
# 구별
# 강남구  80.059970  48.376754  86.629452  537817.0  7243.0  1.000000  85.330216
# 강동구  85.350318  53.827751  85.416667  464027.0  3192.0  0.350109  93.064373
# 강북구  83.050847  67.545872  90.073322  296934.0  3321.0  0.250828  92.204142
# 강서구  74.712644  59.517830  91.670137  573711.0  3353.0  0.463797  93.350600
# 관악구  85.321101  53.407935  80.483054  502628.0  5642.0  0.658870  85.065525

# %%
# 살인검거율에 100이 끼어있었는데 형이 달라서 그런가 에러뜸. 수정.
crime_anal_norm['살인검거율'] = crime_anal_norm['살인검거율'].astype(float)

# %%
# 에러가 다시 난다. 그냥 싹다 float로 통일 시키자
tc = crime_anal_norm.columns
for c in tc :
  print(c)
  crime_anal_norm[c] = crime_anal_norm[c].astype(float)
# Out:
# 살인
# 강도
# 강간·강제추행
# 절도
# 폭력
# 살인검거율
# 강도검거율
# 강간추행검거율
# 절도검거율
# 폭력검거율
# 인구수
# CCTV
# 범죄
# 검거

# %%
# 검거율과 비교
# 전부 실수화 이후 오류 사라짐. 뭐 형이 섞여있었나보다
sns.pairplot(crime_anal_norm, x_vars=["인구수", "CCTV"], y_vars=["살인검거율", "폭력검거율"], kind='reg', height=3)
plt.show()

# %%
# 기존의 검거(최대 500)를 최대값을 100의 기준으로 잡고 비율 환산. 정규화의 일종
tmp_max = crime_anal_norm['검거'].max()
crime_anal_norm['검거'] = crime_anal_norm['검거']/tmp_max * 100
crime_anal_norm_sort = crime_anal_norm.sort_values(by='검거', ascending=False)
crime_anal_norm_sort.head()
# Out:
#            살인        강도   강간·강제추행        절도        폭력  살인검거율  강도검거율  \
# 구별
# 종로구  0.090909  0.727273  0.264657  0.271719  0.187220  100.0  100.0
# 성북구  0.181818  0.090909  0.147404  0.166975  0.133782  100.0  100.0
# 강서구  0.181818  0.636364  0.319933  0.689464  0.491405  100.0  100.0
# 중랑구  0.090909  0.181818  0.134003  0.391867  0.318012  100.0  100.0
# 강동구  0.363636  0.454545  0.145729  0.492914  0.293722  100.0  100.0
#
#         강간추행검거율      절도검거율      폭력검거율       인구수    CCTV        범죄          검거
# 구별
# 종로구  100.000000  70.982483  85.255198  152212.0  1966.0  0.308355  100.000000
# 성북구   81.645570  62.554681  88.434903  441855.0  4957.0  0.144177   94.826703
# 강서구   74.712644  59.517830  91.670137  573711.0  3353.0  0.463797   93.350600
# 중랑구   80.666667  58.488064  85.906040  389928.0  4193.0  0.223322   93.166520
# 강동구   85.350318  53.827751  85.416667  464027.0  3192.0  0.350109   93.064373

# %%
col
# Out:
# Index(['살인', '강도', '강간·강제추행', '절도', '폭력'], dtype='object')

# %%
con_list
# Out:
# Index(['살인검거율', '강도검거율', '강간추행검거율', '절도검거율', '폭력검거율'], dtype='object')

# %%
# plt
plt.figure(figsize = (6,6))
sns.heatmap(crime_anal_norm_sort[con_list], annot = True, fmt='.2f', linewidths=.5)
plt.title('범죄 검거 비율(정규화된 검거의 합으로 정렬)')
plt.show()

# %%
# plt
target_col = ['강간·강제추행', '강도', '살인', '절도', '폭력', '범죄']

crime_anal_norm['범죄'] = crime_anal_norm['범죄'] / 5
crime_anal_norm_sort = crime_anal_norm.sort_values(by = '범죄', ascending = False)

plt.figure(figsize = (8,8))
sns.heatmap(crime_anal_norm_sort[target_col], annot = True, fmt='.2f', linewidths=.5)
plt.title('범죄 비율(정규화된 발생 건수로 정렬)')
plt.show()

# %%
crime_anal_norm.to_csv('/content/drive/MyDrive/Colab Notebooks/WQ/파이썬으로 데이터 주무르기 4주완성/Data/02. crime_Seoul.csv', encoding = 'utf-8')

# %%
import folium

# %%
map_osm = folium.Map(location = [45.5236, -122.6750])
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e74865e3ad9dc3107e2a8f4fdbaca21 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e74865e3ad9dc3107e2a8f4fdbaca21&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e74865e3ad9dc3107e2a8f4fdbaca21 = L.map(
#                 &quot;map_7e74865e3ad9dc3107e2a8f4fdbaca21&quot;,
#                 {
#                     center: [45.5236, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3bf4a092222624782551247c609812a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7e74865e3ad9dc3107e2a8f4fdbaca21);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 타일, 초기 확대율. 근데 곧 못쓴다.
stamen = folium.Map(location = [45.5236, -122.6750], zoom_start = 13, tiles='Stamen Toner')
stamen
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb6a1e3bfadf267edca956600a2a9ed5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb6a1e3bfadf267edca956600a2a9ed5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb6a1e3bfadf267edca956600a2a9ed5 = L.map(
#                 &quot;map_bb6a1e3bfadf267edca956600a2a9ed5&quot;,
#                 {
#                     center: [45.5236, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ebd3237b054b4b960d45ba6cf9a03106 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bb6a1e3bfadf267edca956600a2a9ed5);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
loc = [45.5236, -122.6750]

# %%
map_2 = folium.Map(location = loc, zoom_start = 13)
folium.Marker(location = loc, popup='The Waterfront').add_to(map_2)
folium.CircleMarker(loc, radius = 50, popup='Laurelhurst Park', color = '#3186cc', fill_color = '#3186cc').add_to(map_2)
map_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4eab27f8654df9d000e3166e876e4de7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4eab27f8654df9d000e3166e876e4de7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4eab27f8654df9d000e3166e876e4de7 = L.map(
#                 &quot;map_4eab27f8654df9d000e3166e876e4de7&quot;,
#                 {
#                     center: [45.5236, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd47103070348e47bed9d2a98dc323cf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4eab27f8654df9d000e3166e876e4de7);
#
#
#             var marker_2e55882e07681000841705b8caee6bab = L.marker(
#                 [45.5236, -122.675],
#                 {}
#             ).addTo(map_4eab27f8654df9d000e3166e876e4de7);
#
#
#         var popup_d20ff663fb515a0493a518cc08edf017 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_57c2cb881e05ac1e957e4768a77a9c6e = $(`&lt;div id=&quot;html_57c2cb881e05ac1e957e4768a77a9c6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Waterfront&lt;/div&gt;`)[0];
#                 popup_d20ff663fb515a0493a518cc08edf017.setContent(html_57c2cb881e05ac1e957e4768a77a9c6e);
#
#
#
#         marker_2e55882e07681000841705b8caee6bab.bindPopup(popup_d20ff663fb515a0493a518cc08edf017)
#         ;
#
#
#
#
#             var circle_marker_801accfbb03f1ea2e25be247e84dd8b3 = L.circleMarker(
#                 [45.5236, -122.675],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4eab27f8654df9d000e3166e876e4de7);
#
#
#         var popup_9758b0fe3dea599b89d0b293c9229aab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f9960956b03e260a72fb40ad5bb3c3e0 = $(`&lt;div id=&quot;html_f9960956b03e260a72fb40ad5bb3c3e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Laurelhurst Park&lt;/div&gt;`)[0];
#                 popup_9758b0fe3dea599b89d0b293c9229aab.setContent(html_f9960956b03e260a72fb40ad5bb3c3e0);
#
#
#
#         circle_marker_801accfbb03f1ea2e25be247e84dd8b3.bindPopup(popup_9758b0fe3dea599b89d0b293c9229aab)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 실업률. 주별
state_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/WQ/파이썬으로 데이터 주무르기 4주완성/Data/02. folium_US_Unemployment_Oct2012.csv', encoding = 'cp949')
state_data.head()
# Out:
#   State  Unemployment
# 0    AL           7.1
# 1    AK           6.8
# 2    AZ           8.1
# 3    AR           7.2
# 4    CA          10.1

# %%
# json타입 경계선 데이터
#
state_geo = '/content/drive/MyDrive/Colab Notebooks/WQ/파이썬으로 데이터 주무르기 4주완성/Data/02. folium_us-states.json'

map = folium.Map(location=[40,-98], zoom_start=4)
map.choropleth(geo_data=state_geo, data=state_data, columns=['State', 'Unemployment'], key_on='feature.id', fill_color='YlGn', legend_name='Unemployment Rate (%)')
map
# Out:
# /usr/local/lib/python3.10/dist-packages/folium/folium.py:465: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1cebb73516139733c00727c73ae1b614 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1cebb73516139733c00727c73ae1b614&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1cebb73516139733c00727c73ae1b614 = L.map(
#                 &quot;map_1cebb73516139733c00727c73ae1b614&quot;,
#                 {
#                     center: [40.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_91b8bed10cbf9c34f8e9307dea6424fd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1cebb73516139733c00727c73ae1b614);
#
#
#             var choropleth_7c36ebfcc5ad1d4b282183c4d11cb579 = L.featureGroup(
#                 {}
#             ).addTo(map_1cebb73516139733c00727c73ae1b614);
#
#
#         function geo_json_71996bda1d7bf0a47e17842fb39b9adf_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AZ&quot;: case &quot;CT&quot;: case &quot;FL&quot;: case &quot;GA&quot;: case &quot;IL&quot;: case &quot;IN&quot;: case &quot;KY&quot;: case &quot;MI&quot;: case &quot;MS&quot;: case &quot;NY&quot;: case &quot;OR&quot;: case &quot;PA&quot;: case &quot;SC&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;NV&quot;: case &quot;NJ&quot;: case &quot;NC&quot;: case &quot;RI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;HI&quot;: case &quot;IA&quot;: case &quot;OK&quot;: case &quot;SD&quot;: case &quot;UT&quot;: case &quot;VT&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;ID&quot;: case &quot;KS&quot;: case &quot;LA&quot;: case &quot;MA&quot;: case &quot;MN&quot;: case &quot;MO&quot;: case &quot;MT&quot;: case &quot;NH&quot;: case &quot;TX&quot;: case &quot;VA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;NE&quot;: case &quot;ND&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_71996bda1d7bf0a47e17842fb39b9adf_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_71996bda1d7bf0a47e17842fb39b9adf = L.geoJson(null, {
#                 onEachFeature: geo_json_71996bda1d7bf0a47e17842fb39b9adf_onEachFeature,
#
#                 style: geo_json_71996bda1d7bf0a47e17842fb39b9adf_styler,
#         });
#
#         function geo_json_71996bda1d7bf0a47e17842fb39b9adf_add (data) {
#             geo_json_71996bda1d7bf0a47e17842fb39b9adf
#                 .addData(data)
#                 .addTo(choropleth_7c36ebfcc5ad1d4b282183c4d11cb579);
#         }
#             geo_json_71996bda1d7bf0a47e17842fb39b9adf_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AL&quot;, &quot

# %%
# skorea_municipalities_geo_simple.json
# 02. skorea_municipalities_geo_simple.json

# %%
import json

# %%
geo_path = '/content/drive/MyDrive/Colab Notebooks/WQ/파이썬으로 데이터 주무르기 4주완성/Data/02. skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# %%
# 경계선, 영역을 설정하고 살인수치(0-1)에 따라 색으로 표현
map = folium.Map(location=[37.5502,126.982], zoom_start=11)
map.choropleth(geo_data=geo_str,
               data=crime_anal_norm['살인'],
               columns=[crime_anal_norm.index, crime_anal_norm['살인']],
               key_on='feature.id',
               fill_color='PuRd', legend_name='살인 Rate (%)')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de12f909ee2a17dae43634dae73f8738 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de12f909ee2a17dae43634dae73f8738&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de12f909ee2a17dae43634dae73f8738 = L.map(
#                 &quot;map_de12f909ee2a17dae43634dae73f8738&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5491562085c7e6575b7fd55559e310ec = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_de12f909ee2a17dae43634dae73f8738);
#
#
#             var choropleth_a3b4da494e804573e2aff832150ae396 = L.featureGroup(
#                 {}
#             ).addTo(map_de12f909ee2a17dae43634dae73f8738);
#
#
#         function geo_json_2de7288b4e0062f68e938f0135bd827c_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uad00\uc545\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dd1c77&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_2de7288b4e0062f68e938f0135bd827c_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2de7288b4e0062f68e938f0135bd827c = L.geoJson(null, {
#                 onEachFeature: geo_json_2de7288b4e0062f68e938f0135bd827c_onEachFeature,
#
#                 style: geo_json_2de7288b4e0062f68e938f0135bd827c_styler,
#         });
#
#         function geo_json_2de7288b4e0062f68e938f0135bd827c_add (data) {
#             geo_json_2de7288b4e0062f68e938f0135bd827c
#                 .addData(data)
#                 .addTo(choropleth_a3b4da494e804573e2aff832150ae396);
#         }
#             geo_json_2de7288b4e0062f68e938f0135bd827c_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [127.11117085201238, 37.485708381512445], [127.0719146000724, 37.50224013587669], [127.0690698130372, 37.522279423505026]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uc1a1\ud30c\uad6c&quot;, &quot;propert

# %%
# 경계선, 영역을 설정하고 강간수치(0-1)에 따라 색으로 표현
# 마포구가 치고 올라왔다
map = folium.Map(location=[37.5502,126.982], zoom_start=11)
map.choropleth(geo_data=geo_str,
               data=crime_anal_norm['강간·강제추행'],
               columns=[crime_anal_norm.index, crime_anal_norm['강간·강제추행']],
               key_on='feature.id',
               fill_color='PuRd', legend_name='강간·강제추행 Rate (%)')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_364922910c42ec7d03a08e917680be11 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_364922910c42ec7d03a08e917680be11&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_364922910c42ec7d03a08e917680be11 = L.map(
#                 &quot;map_364922910c42ec7d03a08e917680be11&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd1f515d36c5ddbdfa7789485089a142 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_364922910c42ec7d03a08e917680be11);
#
#
#             var choropleth_8e28c55a81d224a88343daecae9779c7 = L.featureGroup(
#                 {}
#             ).addTo(map_364922910c42ec7d03a08e917680be11);
#
#
#         function geo_json_c8ee5d6fec1d676fcaca128e0c51ed13_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;: case &quot;\uc911\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_c8ee5d6fec1d676fcaca128e0c51ed13_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c8ee5d6fec1d676fcaca128e0c51ed13 = L.geoJson(null, {
#                 onEachFeature: geo_json_c8ee5d6fec1d676fcaca128e0c51ed13_onEachFeature,
#
#                 style: geo_json_c8ee5d6fec1d676fcaca128e0c51ed13_styler,
#         });
#
#         function geo_json_c8ee5d6fec1d676fcaca128e0c51ed13_add (data) {
#             geo_json_c8ee5d6fec1d676fcaca128e0c51ed13
#                 .addData(data)
#                 .addTo(choropleth_8e28c55a81d224a88343daecae9779c7);
#         }
#             geo_json_c8ee5d6fec1d676fcaca128e0c51ed13_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [127.11117085201238, 37.485708381512445], [127.0719146000724, 37.50224013587669], [127.0690698130372, 37.522279423505026]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uc1a1\ud30c\uad6c&quot;, &quot;properties&quot;: {&quot;

# %%
# 경계선, 영역을 설정하고 범죄수치(0-1)에 따라 색으로 표현
# 강남의 압승
map = folium.Map(location=[37.5502,126.982], zoom_start=11)
map.choropleth(geo_data=geo_str,
               data=crime_anal_norm['범죄'],
               columns=[crime_anal_norm.index, crime_anal_norm['범죄']],
               key_on='feature.id',
               fill_color='PuRd', legend_name='범죄 Rate (%)')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f68b3edf55e2b5484c88c848261592d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f68b3edf55e2b5484c88c848261592d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f68b3edf55e2b5484c88c848261592d = L.map(
#                 &quot;map_1f68b3edf55e2b5484c88c848261592d&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d5c12d46e1a5893c1ef2251d50fe2a8a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1f68b3edf55e2b5484c88c848261592d);
#
#
#             var choropleth_7d1389d13a2adf9c21974da87aef38e0 = L.featureGroup(
#                 {}
#             ).addTo(map_1f68b3edf55e2b5484c88c848261592d);
#
#
#         function geo_json_f8097dd4e421a2bc1ea424a68e6d1fed_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_f8097dd4e421a2bc1ea424a68e6d1fed_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f8097dd4e421a2bc1ea424a68e6d1fed = L.geoJson(null, {
#                 onEachFeature: geo_json_f8097dd4e421a2bc1ea424a68e6d1fed_onEachFeature,
#
#                 style: geo_json_f8097dd4e421a2bc1ea424a68e6d1fed_styler,
#         });
#
#         function geo_json_f8097dd4e421a2bc1ea424a68e6d1fed_add (data) {
#             geo_json_f8097dd4e421a2bc1ea424a68e6d1fed
#                 .addData(data)
#                 .addTo(choropleth_7d1389d13a2adf9c21974da87aef38e0);
#         }
#             geo_json_f8097dd4e421a2bc1ea424a68e6d1fed_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [127.11117085201238, 37.485708381512445], [127.0719146000724, 37.50224013587669], [127.0690698130372, 37.522279423505026]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uc1a1\ud30c\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11240&quot;, &quot;name&quot;: &quot;\uc1a1\ud30c\uad6c&quot;, &quot;name_eng&quot;

# %%
crime_anal_norm['lat'] = station_lat
crime_anal_norm['lat'] = station_lat

# %%
# !pip install googlemaps
# Out:
# Collecting googlemaps
#   Downloading googlemaps-4.10.0.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests<3.0,>=2.20.0 in /usr/local/lib/python3.10/dist-packages (from googlemaps) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2023.7.22)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py) ... done
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40713 sha256=0133059e641cd860b936a7ade4f834c33b9cec14649ee7626f60cdf6aac92252
#   Stored in directory: /root/.cache/pip/wheels/17/f8/79/999d5d37118fd35d7219ef57933eb9d09886c4c4503a800f84
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.10.0

# %%
# 경찰서 위도, 경도 얻기.
# 데이터 형식이 바뀌어서 필요가 없어졌기에 생략하고 넘어갔는데, 필요하게 됬다.
import googlemaps
import requests

# %%
# 우선 주소와 경찰서 이름이 담긴 공공데이터 확보
# https://www.data.go.kr/data/15054711/fileData.do
#

# %%
# 구글 무료계정이 옛날에 써서 만료되었기에 그냥 카카오API로 대용한다.
api_key = 'eb1b95f4dc278d870bd954c6ee7549bd'

address = '서울특별시 강남구 역삼동'

base_url = f'https://dapi.kakao.com/v2/local/search/address.json?query={address}'
headers = {'Authorization': f'KakaoAK {api_key}'}
response = requests.get(base_url, headers=headers)

if response.status_code == 200:
    data = response.json()
    if data['documents']:
        for result in data['documents']:
            print(f"주소: {result['address_name']}, 위도: {result['y']}, 경도: {result['x']}")
    else:
        print("검색 결과가 없습니다.")
else:
    print(f"API 요청 실패. 상태 코드: {response.status_code}")
# Out:
# 주소: 서울 강남구 역삼동, 위도: 37.4953666908089, 경도: 127.03306536185
# 주소: 서울 강남구 역삼1동, 위도: 37.4954171091244, 경도: 127.033201083326
# 주소: 서울 강남구 역삼2동, 위도: 37.4959639052057, 경도: 127.046839198832

# %%
# 경찰청_경찰관서 위치 주소 현황_20230811.csv
